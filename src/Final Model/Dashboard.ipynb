# %%
# Scheduled Refresh of Predictions: 16:30 PM every weekday
from Functions import refreshPredictions
import schedule
import time

# set the schedule to run every weekday at 1630
schedule.every().monday.at("16:30").do(refreshPredictions)
schedule.every().tuesday.at("16:30").do(refreshPredictions)
schedule.every().wednesday.at("16:30").do(refreshPredictions)
schedule.every().thursday.at("16:30").do(refreshPredictions)
schedule.every().friday.at("16:30").do(refreshPredictions)

# run the schedule
while True:
    schedule.run_pending()
    time.sleep(3600) # 3600 seconds = 1 hour

# %%
# Backup - run it once.
from Functions import refreshPredictions
refreshPredictions()
# Out:
# Symbol:  SU.TO
# Predicting Close...
# Model Loaded
# Predicting High...
# Model Loaded
# Predicting Low...
# Model Loaded
# Predicting Open...
# Model Loaded
# Predicting Median Price...
# Model Loaded
# Symbol:  TVE.TO
# Predicting Close...
# Model Loaded
# Predicting High...
# Model Loaded
# Predicting Low...
# Model Loaded
# Predicting Open...
# Model Loaded
# Predicting Median Price...
# Model Loaded
# Symbol:  CVE.TO
# Predicting Close...
# Model Loaded
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.0094
# Epoch 2/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0093
# Epoch 3/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0091
# Epoch 4/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0087
# Epoch 5/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0083
# Epoch 6/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0079
# Epoch 7/100
# ...
