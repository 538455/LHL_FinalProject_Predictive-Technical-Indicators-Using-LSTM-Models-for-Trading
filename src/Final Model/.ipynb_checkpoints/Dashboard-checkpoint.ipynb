# %%
# Daily Prediction
from Functions import dailyPrediction
SU = dailyPrediction('SU.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)
# Out:
# Symbol:  SU.TO
# Predicting Close...
# Model Loaded
# Predicting High...
# Model Loaded
# Predicting Low...
# Model Loaded
# Predicting Open...
# Model Loaded
# Predicting Median Price...
# Model Loaded
#
# Success rate: 27.21 %
# Daily Average:  0.76 %
#
# When Missed:
# Take a loss:  88 % of the time...      Average loss:  -2.21 %
# Make a gain:  12 % of the time...      Average gain:  0.4 %
#
# 2022 profit: 81 %
# # Transactions: 82

# %%
# Daily Prediction
TVE = dailyPrediction('TVE.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)
# Out:
# Symbol:  TVE.TO
# Predicting Close...
# Model Loaded
# Predicting High...
# Model Loaded
# Predicting Low...
# Model Loaded
# Predicting Open...
# Model Loaded
# Predicting Median Price...
# Model Loaded
#
# Success rate: 27.41 %
# Daily Average:  1.3 %
#
# When Missed:
# Take a loss:  90 % of the time...      Average loss:  -5.7 %
# Make a gain:  10 % of the time...      Average gain:  1.39 %
#
# 2022 profit: 77 %
# # Transactions: 79

# %%
# Daily Prediction
CVE = dailyPrediction('CVE.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)
# Out:
# Symbol:  CVE.TO
# Predicting Close...
# Model Not Found, training new model
# Epoch 1/100
# 520/520 [==============================] - 7s 10ms/step - loss: 0.0256
# Epoch 2/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0125
# Epoch 3/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0098
# Epoch 4/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0081
# Epoch 5/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0063
# Epoch 6/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0054
# Epoch 7/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0039
# Epoch 8/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0033
# Epoch 9/100
# 520/520 [==============================] - 5s 10ms/step - loss: 0.0025
# Epoch 10/100
# 312/520 [=================>............] - ETA: 2s - loss: 0.0017

# %%
# Daily Prediction
SBB = dailyPrediction('SBB.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)

# %%
# Daily Prediction
DPM = dailyPrediction('DPM.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)

# %%
# Daily Prediction
GLO = dailyPrediction('GLO.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)

# %%
# Daily Prediction
GWO = dailyPrediction('GWO.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)

# %%
# Daily Prediction
BNS = dailyPrediction('BNS.TO', accuracyPlot=False)

# Cleanup
# Ticker_D_Pred = Ticker_D_Pred.drop(['High_RMSE', 'Low_RMSE', 'Open', 'High', 'Low', 'Close', 'Open_RMSE', 'Close_RMSE', 'Median_Price_RMSE'], axis=1)

# %% [markdown]
# # MVP Model results:

# %%
#plot TVE predictions and close in a plotly graph
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=TVE.index, y=TVE['Close'],
                    mode='lines',
                    name='True'))
                    
# fig.add_trace(go.Scatter(x=TVE.index, y=TVE['Predictions'],
#                     mode='lines',
#                     name='Predictions'))

# draw a shaded area between two lines: Prediction + RMSE and Prediction - RMSE. RMSE = 0.319075
fig.add_trace(go.Scatter(x=TVE.index, y=TVE['Predictions'] + 0.319075, fill=None, mode='lines', line_color='rgba(0,100,80,0.2)', name='RMSE'))
fig.add_trace(go.Scatter(x=TVE.index, y=TVE['Predictions'] - 0.319075, fill='tonexty', mode='lines', line_color='rgba(0,100,80,0.2)'))

fig.show()
